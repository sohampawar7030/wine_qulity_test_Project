# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_test.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
cv1=df.head(100)

# %%
cv=df.tail(100)

# %%
df.count()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
null=df.isnull().sum()

# %%
null
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1138    False
# 1139    False
# 1140    False
# 1141    False
# 1142    False
# Length: 1143, dtype: bool

# %%
sns.catplot(x="quality",data=df,kind="count")

# %%
sns.catplot(x="quality",data=df,y="density")

# %%
plot = plt.figure(figsize=(5,5))

sns.barplot(x="quality",y="volatile acidity",data=df)

plt.suptitle("Ratio")
# Out:
# Text(0.5, 0.98, 'Ratio')

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
sns.catplot(x="citric acid",data=cv1,y="pH")
plt.gcf().set_facecolor("white")

plt.suptitle("Ratio",y=0.900,color="Pink")
# Out:
# Text(0.5, 0.9, 'Ratio')

# %%
plot= plt.figure(figsize=(5,5))
sns.countplot(x="pH",data=cv1)
# Out:
# <AxesSubplot: xlabel='pH', ylabel='count'>

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x="quality",y="residual sugar",data=df)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='residual sugar'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x="quality",y="chlorides",data=df,errcolor="yellow",palette="pastel")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='chlorides'>

# %%
plot = plt.figure(figsize=(5,5))
sns.catplot(x="quality",y="free sulfur dioxide",data=df,color="yellow",palette="pastel")
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13284\562059036.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x="quality",y="free sulfur dioxide",data=df,color="yellow",palette="pastel")

# %%
sns.barplot(x="quality",y="density",data=df)
# Out:
# <AxesSubplot: xlabel='quality', ylabel='density'>

# %%
plot = plt.figure(figsize=(5,5))
sns.barplot(x="quality",y="total sulfur dioxide",data=df,palette="rocket")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
sns.barplot(x="quality",y='sulphates',data=df,palette="viridis")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='sulphates'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap="pink")
# Out:
# <AxesSubplot: >

# %%
df['Id'].value_counts()
# Out:
# 0       1
# 1079    1
# 1087    1
# 1086    1
# 1085    1
#        ..
# 543     1
# 544     1
# 545     1
# 546     1
# 1597    1
# Name: Id, Length: 1143, dtype: int64

# %%
plt.hist(df['alcohol'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram of Alcohol Percentage')
plt.xlabel('Alcohol Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
x=df.drop("quality",axis=1)

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
x.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
y= df['quality'].apply(lambda y_values :1 if y_values>=7 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1138    0
# 1139    0
# 1140    0
# 1141    0
# 1142    0
# Name: quality, Length: 1143, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=rfc.predict(x_test)

# %%
acc = accuracy_score(y_test,y_pred)

# %%
acc
# Out:
# 0.9039301310043668
